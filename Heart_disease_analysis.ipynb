# %% [markdown]
# # Importing libraries and reading the dataset

# %%
# Importing Libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Reading dataset

df=pd.read_csv(r'C:\Users\User\Desktop\iNeuron\heart_disease_dataset - CLN.csv')

# %%
# Displaying the rows

df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 292   57    0   4       140   241    0        0      123      1      0.2
# 293   45    1   1       110   264    0        0      132      0      1.2
# 294   68    1   4       144   193    1        0      141      0      3.4
# 295   57    1   4       130   131    0        0      115      1      1.2
# 296   57    0   2       130   236    0        2      174      0      0.0
#
#      slope  ca  thal  num
# 0        3   0     6    0
# 1        2   3     3    1
# ...

# %% [markdown]
# **Note : In the original dataset it contained 303 observations, but I have excluded 6 observations from the dataset for the analysis due to those observations containing extreme and abnormal values. These extreme values may skew the analysis**

# %% [markdown]
# # Checking and cleaning dataset

# %%
# Displaying the concise summary of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    int64
#  1   sex       297 non-null    int64
#  2   cp        297 non-null    int64
#  3   trestbps  297 non-null    int64
#  4   chol      297 non-null    int64
#  5   fbs       297 non-null    int64
#  6   restecg   297 non-null    int64
#  7   thalach   297 non-null    int64
#  8   exang     297 non-null    int64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    int64
#  11  ca        297 non-null    int64
#  12  thal      297 non-null    int64
#  13  num       297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 32.6 KB

# %% [markdown]
# **Insight : We can see that there are 297 rows and 14 columns and there are no missing values in the dataset**

# %%
# Checking for null values 

df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# **Insight : There are no null values in the dataset**

# %%
# Renaming columns for better understanding of the dataset

df.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
       'exercise_induced_angina', 'st_depression', 'st_slope', 'num_major_vessels', 'thalassemia', 'target']

df.columns
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'resting_blood_pressure',
#        'cholesterol', 'fasting_blood_sugar', 'rest_ecg',
#        'max_heart_rate_achieved', 'exercise_induced_angina', 'st_depression',
#        'st_slope', 'num_major_vessels', 'thalassemia', 'target'],
#       dtype='object')

# %%
# Checking the statistical summary of the dataset

df.describe()
# Out:
#               age         sex  chest_pain_type  resting_blood_pressure  \
# count  297.000000  297.000000       297.000000              297.000000
# mean    54.542088    0.676768         3.158249              131.693603
# std      9.049736    0.468500         0.964859               17.762806
# min     29.000000    0.000000         1.000000               94.000000
# 25%     48.000000    0.000000         3.000000              120.000000
# 50%     56.000000    1.000000         3.000000              130.000000
# 75%     61.000000    1.000000         4.000000              140.000000
# max     77.000000    1.000000         4.000000              200.000000
#
#        cholesterol  fasting_blood_sugar    rest_ecg  max_heart_rate_achieved  \
# count   297.000000           297.000000  297.000000               297.000000
# mean    247.350168             0.144781    0.996633               149.599327
# std      51.997583             0.352474    0.994914                22.941562
# ...

# %% [markdown]
# **Insight : From the above summary we can infer that the minimum age is 29 years and the maximum age is 77 years and the mean age is 54 years, and the median age in the datset in 56 years. The quartile details are given in the 25%, 50% and 75%, the data is divided into 3 quartiles of 4 equal parts, but the mean is effected by outliers and so we need more information to make accurate decisions**

# %%
# Checking the shape of the data

df.hist(figsize=(12,12),layout=(5,3))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'chest_pain_type'}>],
#        [<AxesSubplot:title={'center':'resting_blood_pressure'}>,
#         <AxesSubplot:title={'center':'cholesterol'}>,
#         <AxesSubplot:title={'center':'fasting_blood_sugar'}>],
#        [<AxesSubplot:title={'center':'rest_ecg'}>,
#         <AxesSubplot:title={'center':'max_heart_rate_achieved'}>,
#         <AxesSubplot:title={'center':'exercise_induced_angina'}>],
#        [<AxesSubplot:title={'center':'st_depression'}>,
#         <AxesSubplot:title={'center':'st_slope'}>,
#         <AxesSubplot:title={'center':'num_major_vessels'}>],
#        [<AxesSubplot:title={'center':'thalassemia'}>,
#         <AxesSubplot:title={'center':'target'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Analysis

# %%
# Checking for outliers

df.plot(kind='box',subplots=True,figsize=(12,12),layout=(5,3))
# Out:
# age                           AxesSubplot(0.125,0.749828;0.227941x0.130172)
# sex                        AxesSubplot(0.398529,0.749828;0.227941x0.130172)
# chest_pain_type            AxesSubplot(0.672059,0.749828;0.227941x0.130172)
# resting_blood_pressure        AxesSubplot(0.125,0.593621;0.227941x0.130172)
# cholesterol                AxesSubplot(0.398529,0.593621;0.227941x0.130172)
# fasting_blood_sugar        AxesSubplot(0.672059,0.593621;0.227941x0.130172)
# rest_ecg                      AxesSubplot(0.125,0.437414;0.227941x0.130172)
# max_heart_rate_achieved    AxesSubplot(0.398529,0.437414;0.227941x0.130172)
# exercise_induced_angina    AxesSubplot(0.672059,0.437414;0.227941x0.130172)
# st_depression                 AxesSubplot(0.125,0.281207;0.227941x0.130172)
# st_slope                   AxesSubplot(0.398529,0.281207;0.227941x0.130172)
# num_major_vessels          AxesSubplot(0.672059,0.281207;0.227941x0.130172)
# ...

# %% [markdown]
# **Insight : From the above plots we can see that there outliers in the datset**

# %%
#Count of males and females

df['sex'].value_counts()
# Out:
# 1    201
# 0     96
# Name: sex, dtype: int64

# %% [markdown]
# **Insight : There are 206 males and 96 females**

# %%
# Displaying the count of the males and females

fig = sns.countplot(x='sex',data=df,palette="nipy_spectral_r")

for p in fig.patches:
    fig.annotate(p.get_height() , (p.get_x()+0.35, p.get_height()-60))
plt.title('Count of Males and Females', fontsize=20)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Count', fontsize=15)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# **Insight : As the number of males is comparatively higher than the number of females, we may not get accurate results when we are doing gender comparisons with different features**

# %%
# Checking the rate of heat disease among the males and females with respect to age 

sns.catplot(data=df,x='sex',y='age',hue='target',palette='afmhot')
plt.title('Males and Females Diagnosed with Heart Disease', fontsize=20)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Age', fontsize=15)
# Out:
# Text(26.04390625, 0.5, 'Age')

# %% [markdown]
# **Insight :
# <br>• From the above plot it is understood that females are less likely to have heart disease than males
# <br>• We can also see that chances of females getting a heart disease increases between the age of 55 and 65 years
# <br>• And the chances of males getting a heart disease increases above 45 years of age**

# %%
# Displaying the number of males and females having and not having heart disease

gen = pd.crosstab(df['sex'],df['target'])
print(gen)
gen.plot(kind='bar',stacked=True,grid=False)
plt.title('Male vs Females', fontsize=20)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Count', fontsize=15)
# Out:
# target   0    1
# sex
# 0       71   25
# 1       89  112
# Text(0, 0.5, 'Count')

# %% [markdown]
# **Insight : From the dataset :
# <br>• Females not having heart disease is 71 and having heart disease is 25
# <br>• Males not having heart disease is 89 and having heart disease is 112**

# %%
# Checking the target feature

plt.figure(figsize=(8,8))
labels=[""]
df['target'].value_counts().plot.pie(autopct="%.2f", startangle=90,textprops={'fontsize': 14})
plt.title('Heart Disease Population %', fontsize=20)
plt.ylabel('Target', fontsize=15)
# Out:
# Text(0, 0.5, 'Target')

# %% [markdown]
# <br>O - Heart Disease(absent)
# <br>1 - Heart Disease(present)
# <br>**Insight : From the dataset 46.13% of people have been diagnosed with heart disease**

# %%
# Checking the chestpain type on the basis of target

plt.figure(figsize=(8,6))
plt.xticks(rotation=0, fontsize=18)
sns.countplot(x = df['target'],hue = 'chest_pain_type',data=df)
plt.xlabel("Target",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title('Chest Pain vs Target',fontsize=20)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# **Insight : Patients suffering from asymptomatic chest pain are more susceptible to having heart diseases
# Asymptomatic Chest pain means shows no symptoms of heart disease, it is medically known as silent myocardial infarction**

# %%
# Checking the chestpain type on the basis of sex

plt.figure(figsize=(8,6))
plt.xticks(rotation=0, fontsize=18)
sns.countplot(x=df['sex'], hue='chest_pain_type', data=df)
plt.title('Chest Pain Based On Gender', fontsize=20)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# **Insight : We can see that men are more susceptable from asymptomatic type of Chest Pain**

# %%
# Checking the chestpain type on the basis of age

plt.figure(figsize=(24,8))
plt.xticks(rotation=0, fontsize=18)
sns.countplot(x=df['age'], hue='chest_pain_type', data=df)
plt.title('Chest Pain Based On Age', fontsize=20)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# **Insight : We can see that there is a increase in rate of heart disease between the ages of 50 and 65 and the most common type of chest pain is asymptomatic chest pain**

# %%
# Comparing resting blood pressure and target 

plt.figure(figsize=(8,6))
sns.histplot(data=df,hue='target',x="resting_blood_pressure",multiple="dodge",palette="viridis")
plt.xlabel("Resting Blood Pressure",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title('Resting Blood Pressure VS Target',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Resting Blood Pressure VS Target')

# %% [markdown]
# **Insight :<br>• Individuals with resting blood pressure less than 120 mm Hg have less chance of getting a heart disease
# <br>• Resting blood pressure between 120 to 129 mm Hg indicates you have elevated blood pressure
# <br>• Resting blood pressure between 130 – 139 indicates you have high blood pressure(hypertension) stage 1
# <br>• Resting blood pressure between 140 or higher indicates you have high blood pressure(hypertension) stage 2
# <br>• Resting blood pressure higher than 180 indicates you have hypertensive crysis
# <br> From the above plot we can see that blood pressure 140 or higher indicates that the target individual has heart disease**

# %%
# Comparing fasting blood sugar and target

plt.figure(figsize=(8,6))
sns.countplot(data=df,hue='target',x="fasting_blood_sugar",palette="BuPu_r")
plt.xlabel("Fasting Blood Sugar",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title('Fasting Blood Sugar VS Target',fontsize=20)
plt.show()

# %% [markdown]
# **Insight : Patients having fasting blood suger >120 mg/dl have higher chances of having heart diseases**

# %%
# Comparing fasting blood sugar and target

plt.figure(figsize=(12,6))
sns.histplot(data=df,hue='target',x="cholesterol",multiple="dodge",palette="dark:salmon_r")
plt.xlabel("Cholesterol Level",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title('Cholesterol VS Target',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Cholesterol VS Target')

# %% [markdown]
# **Insight : Individuals having cholesterol level between 250 and above have a higher chances of getting  heart diseases**

# %%
plt.figure(figsize=(8,6))
plt.xticks(rotation=0, fontsize=18)
sns.countplot(x='rest_ecg',hue='target',data=df,palette="Blues")
plt.xlabel("Resting Electrocardiographic Measurement",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title('Resting Electrocardiographic Measurement VS Target',fontsize=20)
plt.show()

# %% [markdown]
# <br>0 : normal
# <br>1 : symmetric T wave
# <br>2 : left vertricular hypertrophy
# <br>**Insight : We can see that the patients diagnosed with symmetric T waves and left vertricular hypertrophy are prone to getting diagnosed with heart diseases**

# %%
# Comparing heart rate and target

plt.figure(figsize=(8,6))
sns.histplot(x='max_heart_rate_achieved',hue='target',multiple='dodge',data=df,palette="vlag")
plt.xlabel("Maximum Heart Rate",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title('Maximum Heart Rate VS Target',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Maximum Heart Rate VS Target')

# %% [markdown]
# **Insight : We can see that patients with heart rate 120 and above have a higher chance of getting diagnosed with heart diseases**

# %%
# Comparing exercise induced angina and target

plt.figure(figsize=(8,6))
plt.xticks(rotation=0, fontsize=18)
sns.countplot(x='exercise_induced_angina',data=df, hue='target',palette='cubehelix')
plt.xlabel("Exercise Induced Angina",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Exercise Induced Angina VS target",fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Insight : Exercise induced anginal pain have slightly higher chances of getting heart diseases than without exercise induced pain**

# %%
# Comparing ST depression angina and target

plt.figure(figsize=(8,6))
sns.histplot(x='st_depression',hue='target',multiple='dodge',data=df,palette="icefire")
plt.xlabel("ST Depression",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("ST Depression VS target",fontsize=20)
# Out:
# Text(0.5, 1.0, 'ST Depression VS target')

# %% [markdown]
# **Insight : People having ST depression induced by exercise relative to rest >1 mm have higher chances of heart diseases**

# %%
# Comparing thalassemia and target

plt.figure(figsize=(8,6))
plt.xticks(rotation=0, fontsize=18)
sns.countplot(x='thalassemia', hue='target', data=df,palette='YlGn_r')
plt.xlabel("Thalasemia",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Thalassemia VS Target",fontsize=20)
plt.show()

# %% [markdown]
# <br>3 = normal
# <br>6 = fixed defect
# <br>7 = reversable defect
# <br>**Insight : People are more prone to heart diseases having fixed defect and reversable defect**
